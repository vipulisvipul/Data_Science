# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
calender=pd.read_csv('C:/Users/Administrator/Desktop/Eda_assignment/calendar.csv')
calender.head()
# Out:
#    listing_id        date available   price
# 0      635756  2019-11-14         t  $67.00
# 1      292285  2019-11-14         f     NaN
# 2      292285  2019-11-13         f     NaN
# 3      292285  2019-11-12         f     NaN
# 4      292285  2019-11-11         f     NaN

# %%
listing=pd.read_csv('C:/Users/Administrator/Desktop/Eda_assignment/listings.csv',encoding='ANSI')
listing.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20181115100559   2018-11-15
# 1   5570   https://www.airbnb.com/rooms/5570  20181115100559   2018-11-15
# 2   8095   https://www.airbnb.com/rooms/8095  20181115100559   2018-11-15
# 3  39516  https://www.airbnb.com/rooms/39516  20181115100559   2018-11-15
# 4  45429  https://www.airbnb.com/rooms/45429  20181115100559   2018-11-15
#
#                                              name  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
# 2                            Sunset Cliffs Studio
# 3                 Art Studio Retreat/Rustic Cabin
# 4                 OB cottage SD--view on waterway
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
# ...

# %%
reviews=pd.read_csv('C:/Users/Administrator/Desktop/Eda_assignment/reviews.csv')
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0           6        8  2008-06-22          415      Terrence
# 1           6     4383  2009-06-22         3762     Christine
# 2           6  1722383  2012-07-16      1864778          Hieu
# 3           6  5595071  2013-07-07       117966        Daryna
# 4           6  5631156  2013-07-08      6563815        Mathew
#
#                                             comments
# 0  Sara is an awesome hostess.  She was very cons...
# 1  My stay at “Craftsmen” was wonderful!  Sara wa...
# 2  This was my first time using Airbnb and Sara m...
# 3  Sara was a very pleasant host! Reservation was...
# 4  Sara was such an amazing hostess! My girlfrien...

# %%
reviews_brief=pd.read_csv('C:/Users/Administrator/Desktop/Eda_assignment/reviews_brief.csv')
reviews_brief.head()
# Out:
#    listing_id        date
# 0           6  2008-06-22
# 1           6  2009-06-22
# 2           6  2012-07-16
# 3           6  2013-07-07
# 4           6  2013-07-08

# %%
listing_brief=pd.read_csv('C:/Users/Administrator/Desktop/Eda_assignment/listings_brief.csv')
listing_brief.head()
# Out:
#       id                                            name  host_id  \
# 0      6  Large Craftsmen w/ yard ~ Perfect for families       29
# 1   5570                   Ocean front condo on the sand     8435
# 2   8095                            Sunset Cliffs Studio      270
# 3  39516                 Art Studio Retreat/Rustic Cabin   169649
# 4  45429                 OB cottage SD--view on waterway   197919
#
#                            host_name  neighbourhood_group neighbourhood  \
# 0                               Sara                  NaN   North Hills
# 1  Jef Karchin'S MISSIONBEACHRETREAT                  NaN   Mission Bay
# 2                              Marin                  NaN   Ocean Beach
# 3                    Chris  And Jean                  NaN   North Hills
# 4                            Melissa                  NaN   Loma Portal
#
#     latitude   longitude        room_type  price  minimum_nights  \
# 0  32.753993 -117.129705  Entire home/apt    295               2
# ...

# %%
neighbor=pd.read_csv('C:/Users/Administrator/Desktop/Eda_assignment/neighbourhoods.csv')
neighbor.head()
# Out:
#    neighbourhood_group                neighbourhood
# 0                  NaN               Allied Gardens
# 1                  NaN                   Alta Vista
# 2                  NaN  Amphitheater And Water Park
# 3                  NaN                  Balboa Park
# 4                  NaN                  Bario Logan

# %% [markdown]
# ## Number of accommodation available in every Country

# %%
listing['room_type'].isnull().sum()
# Out:
# 0

# %%
listing['smart_location'].isnull().sum()
# Out:
# 0

# %%
listing['room_type'].value_counts()
# Out:
# Entire home/apt    8304
# Private room       3426
# Shared room         192
# Name: room_type, dtype: int64

# %%
listing['country'].value_counts()
# Out:
# United States    11914
# Mexico               8
# Name: country, dtype: int64

# %%
pd.set_option('display.max_columns',1000)
pd.set_option('display.max_rows',1000)

# %%
listing['price']=listing['price'].str.replace(r'$', '')

# %%
listing['price']=listing['price'].str.extract(r'([0-9,\d\d\d\d\d]*.[\d])')[0].str.replace(',','')
listing['price']=listing['price'].astype('float64')

# %%
listing[listing['country']=='Mexico']['price'].max()
# Out:
# 158.0

# %%
listing[listing['country']=='Mexico']['price'].min()
# Out:
# 16.0

# %%
listing[listing['country']=='Mexico']['price'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
listing[listing['country']=='Mexico']['smart_location']
# Out:
# 11070    Tijuana, Mexico
# 11560    Tijuana, Mexico
# 11595    Tijuana, Mexico
# 11638    Tijuana, Mexico
# 11716    Tijuana, Mexico
# 11755    Tijuana, Mexico
# 11767    Tijuana, Mexico
# 11773    Tijuana, Mexico
# Name: smart_location, dtype: object

# %%
listing[(listing['country']=='Mexico')][['name','price']].sort_values(by='price',ascending=False)
# Out:
#                                                     name  price
# 11716  â˜€ï¸OceanviewsÂºClose to Downtown Playasâˆš ...  158.0
# 11560                                        DALI SUITES   74.0
# 11755                Large loft one block f/ border #107   65.0
# 11595      BUSINESS VINTAGE STUDIO FOR 3 Crossing Border   24.0
# 11767  Honeymooners mini Loft 70 meters from Border f...   24.0
# 11638       MINI STUDIO FOR 3 AMIGOS CROSSING BORDERLINE   23.0
# 11773      HONEYMOONERS 2 MINILOFT FOR 3 CROSSING BORDER   19.0
# 11070                                           Mi lugar   16.0

# %%
d={}
for i in range(1,50):
    q=listing[(listing['room_type']=='Private room') & (listing['accommodates']==i) & (listing['country']=='Mexico')]['room_type'].count()
    d[i]=q

# %%
listing[listing['country']=='Mexico'].head()
# Out:
#              id                            listing_url       scrape_id  \
# 11070  28228183  https://www.airbnb.com/rooms/28228183  20181115100559
# 11560  29315679  https://www.airbnb.com/rooms/29315679  20181115100559
# 11595  29411171  https://www.airbnb.com/rooms/29411171  20181115100559
# 11638  29494985  https://www.airbnb.com/rooms/29494985  20181115100559
# 11716  29670134  https://www.airbnb.com/rooms/29670134  20181115100559
#
#       last_scraped                                               name  \
# 11070   2018-11-15                                           Mi lugar
# 11560   2018-11-15                                        DALI SUITES
# 11595   2018-11-15      BUSINESS VINTAGE STUDIO FOR 3 Crossing Border
# 11638   2018-11-15       MINI STUDIO FOR 3 AMIGOS CROSSING BORDERLINE
# 11716   2018-11-15  â˜€ï¸OceanviewsÂºClose to Downtown Playasâˆš ...
#
#                                                  summary  \
# ...

# %%
listing['cleaning_fee']=listing['cleaning_fee'].str.replace(r'$', '')
listing['cleaning_fee']=listing['cleaning_fee'].str.extract(r'([0-9,\d\d\d\d\d]*.[\d])')[0].str.replace(',','')
listing['cleaning_fee']=listing['cleaning_fee'].astype('float64')
listing[listing['country']=='Mexico']['cleaning_fee'].max()
# Out:
# 55.0

# %%
listing['security_deposit']=listing['security_deposit'].str.replace(r'$', '')
listing['security_deposit']=listing['security_deposit'].str.extract(r'([0-9,\d\d\d\d\d]*.[\d])')[0].str.replace(',','')
listing['security_deposit']=listing['security_deposit'].astype('float64')
listing[listing['country']=='Mexico']['security_deposit'].max()
# Out:
# 300.0

# %%
listing[listing['country']=='Mexico']['minimum_nights'].sort_values(ascending=False)
# Out:
# 11560    3
# 11773    1
# 11767    1
# 11755    1
# 11716    1
# 11638    1
# 11595    1
# 11070    1
# Name: minimum_nights, dtype: int64

# %%
listing[listing['country']=='Mexico']['maximum_nights'].sort_values(ascending=False)
# Out:
# 11755    1125
# 11716    1125
# 11560    1125
# 11595     180
# 11767      90
# 11773      30
# 11638      30
# 11070      30
# Name: maximum_nights, dtype: int64

# %% [markdown]
# ## In mexico,total 8 accomodation are available
# * 2- Entire home/apt,(5,16) people can accomodate
# * 6-Private room,(1,2,3*3) people can accomodates(3 rooms in which 3 people can stay)
# * maximum price of the hotel in mexico is $ 158 and minimum is $ 16
# * maximum hotel in mexico has a price of $ 24 & all are located in tijuana,Mexico
# * Name of the accomodation with maximun price is 'â˜€ï¸OceanviewsÂºClose to Downtown Playasâˆš' and minimun price is  'Mi lugar'
#
# * The rating given for the hotels is very less so we can't consider rating.
# * The hotel with maximun price is only available for 90 days from 2018-11-15.
# * DALI SUITES has a stay of 3 minimum nights
# * The Maximum cleaning fees and security deposit is for the 'OceanviewsÂºClose to Downtown Playasâˆš' which is $ 55 & $300.

# %%
listing[listing['country']=='United States'].head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0      6      https://www.airbnb.com/rooms/6  20181115100559   2018-11-15
# 1   5570   https://www.airbnb.com/rooms/5570  20181115100559   2018-11-15
# 2   8095   https://www.airbnb.com/rooms/8095  20181115100559   2018-11-15
# 3  39516  https://www.airbnb.com/rooms/39516  20181115100559   2018-11-15
# 4  45429  https://www.airbnb.com/rooms/45429  20181115100559   2018-11-15
#
#                                              name  \
# 0  Large Craftsmen w/ yard ~ Perfect for families
# 1                   Ocean front condo on the sand
# 2                            Sunset Cliffs Studio
# 3                 Art Studio Retreat/Rustic Cabin
# 4                 OB cottage SD--view on waterway
#
#                                              summary  \
# 0  Our Beautiful Craftsmen house has all the mode...
# 1  Missionbeachretreat.   Great Ocean Front Condo...
# ...

# %%
listing.shape
# Out:
# (11922, 96)

# %%
d1={}
for i in range(1,50):
    ax=listing[(listing['room_type']=='Entire home/apt') & (listing['accommodates']==i) & (listing['country']=='United States')]['room_type'].count()
    d1[i]=ax
d1
# Out:
# {1: 60,
#  2: 1444,
#  3: 779,
#  4: 2097,
#  5: 554,
#  6: 1446,
#  7: 266,
#  8: 792,
#  9: 100,
#  10: 333,
#  11: 59,
#  12: 161,
#  13: 11,
#  14: 61,
#  15: 25,
#  16: 107,
#  17: 1,
#  18: 2,
#  19: 0,
#  20: 2,
#  21: 1,
#  22: 0,
#  23: 0,
#  24: 0,
#  25: 0,
#  26: 0,
#  27: 0,
#  28: 0,
#  29: 0,
#  30: 0,
#  31: 0,
#  32: 0,
#  33: 0,
#  34: 0,
#  35: 0,
#  36: 0,
#  37: 0,
#  38: 0,
#  39: 0,
#  40: 1,
#  41: 0,
#  42: 0,
#  43: 0,
#  44: 0,
#  45: 0,
#  46: 0,
#  47: 0,
#  48: 0,
#  49: 0}

# %%
d2={}
for i in range(1,50):
    axz=listing[(listing['room_type']=='Private room') & (listing['accommodates']==i) & (listing['country']=='United States')]['room_type'].count()
    d2[i]=axz
d2
# Out:
# {1: 547,
#  2: 2326,
#  3: 221,
#  4: 239,
#  5: 25,
#  6: 36,
#  7: 8,
#  8: 8,
#  9: 1,
#  10: 3,
#  11: 0,
#  12: 0,
#  13: 0,
#  14: 1,
#  15: 0,
#  16: 5,
#  17: 0,
#  18: 0,
#  19: 0,
#  20: 0,
#  21: 0,
#  22: 0,
#  23: 0,
#  24: 0,
#  25: 0,
#  26: 0,
#  27: 0,
#  28: 0,
#  29: 0,
#  30: 0,
#  31: 0,
#  32: 0,
#  33: 0,
#  34: 0,
#  35: 0,
#  36: 0,
#  37: 0,
#  38: 0,
#  39: 0,
#  40: 0,
#  41: 0,
#  42: 0,
#  43: 0,
#  44: 0,
#  45: 0,
#  46: 0,
#  47: 0,
#  48: 0,
#  49: 0}

# %%
d3={}
for i in range(1,50):
    paxz=listing[(listing['room_type']=='Shared room') & (listing['accommodates']==i) & (listing['country']=='United States')]['room_type'].count()
    d3[i]=paxz
d3
# Out:
# {1: 113,
#  2: 34,
#  3: 10,
#  4: 18,
#  5: 0,
#  6: 8,
#  7: 2,
#  8: 3,
#  9: 0,
#  10: 2,
#  11: 0,
#  12: 1,
#  13: 0,
#  14: 0,
#  15: 0,
#  16: 1,
#  17: 0,
#  18: 0,
#  19: 0,
#  20: 0,
#  21: 0,
#  22: 0,
#  23: 0,
#  24: 0,
#  25: 0,
#  26: 0,
#  27: 0,
#  28: 0,
#  29: 0,
#  30: 0,
#  31: 0,
#  32: 0,
#  33: 0,
#  34: 0,
#  35: 0,
#  36: 0,
#  37: 0,
#  38: 0,
#  39: 0,
#  40: 0,
#  41: 0,
#  42: 0,
#  43: 0,
#  44: 0,
#  45: 0,
#  46: 0,
#  47: 0,
#  48: 0,
#  49: 0}

# %%
qq=listing[listing['country']=='United States']['room_type'].value_counts()
qq.plot(kind='bar')

# %% [markdown]
# ## USA
# * There are 8302  Entire home/apt in which there is only 1 which can accomodate 40 people at a time(price=$10000),maximum          accomodate 2 people.
# * There are 3402 Private room in which there are 5 which can accomodate 16(max price= 3000)people at a time,maximum accomodate    2 people.
# * There are 192 Shared room in Which there is only 1 which can accomodate 16(max price= 350) people at a time, maximum             accomodate 1 people.
# * There is only one stay whose review are greater than 500 and get an accuracy rating of 10,its name is '"Granada House" Urban     Farm Cottage' ,price is  99.

# %% [markdown]
# ## Distribution of price for listing

# %%
sns.distplot(listing["price"],axlabel="Distribution of price")

# %% [markdown]
# ### pricing vs bathroom

# %%
sns.barplot(x = listing.bathrooms, y = listing.price)

# %% [markdown]
# ## pricing vs bedroom

# %%
sns.barplot(x = listing.bedrooms, y = listing.price)

# %% [markdown]
# ## pricing vs no of persons can be accomodated

# %%
sns.barplot(x = listing.accommodates, y = listing.price)

# %% [markdown]
# ## top 10 neighbourhood places preferred

# %%
listing.groupby("neighbourhood")["review_scores_rating"].sum().sort_values(ascending=False).head(10).plot(kind="bar")

# %% [markdown]
# ## ratings vs pricing

# %%
listing.plot.scatter(y='price', x='review_scores_rating')

# %% [markdown]
# ## which city has more price

# %%
listing.groupby('city')[['price']].sum().sort_values(by='price',ascending=False).head(10)
# Out:
#                        price
# city
# San Diego          2299840.0
# La Jolla            151326.0
# Chula Vista          33359.0
# Del Mar              26966.0
# Ø³Ø§Ù† Ø¯ÙŠÙŠØºÙˆ     2500.0
# Mission Beach         2275.0
# Alpine                2262.0
# San Diego             1765.0
# La Jolla              1730.0
# LA JOLLA              1038.0

# %% [markdown]
# ## super host vs rating

# %%
super_rating=listing.groupby("host_is_superhost")["review_scores_rating"].sum()
super_rating
# Out:
# host_is_superhost
# f    559570.0
# t    357547.0
# Name: review_scores_rating, dtype: float64

# %%
import matplotlib.pyplot as plt
labels=np.array(super_rating.index)
sizes=super_rating.values
colors=['red','blue']
plt.figure(figsize=(5,3))
plt.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('rating vs super host')
plt.axis('equal')
# Out:
# (-1.1119047963755213,
#  1.100566895065501,
#  -1.1204490312690472,
#  1.1140232944121313)

# %% [markdown]
# ## property type vs price

# %%
listing.property_type.unique()
# Out:
# array(['House', 'Condominium', 'Guesthouse', 'Tiny house', 'Guest suite',
#        'Apartment', 'Bed and breakfast', 'Townhouse', 'Bungalow',
#        'Cottage', 'Loft', 'Camper/RV', 'Treehouse', 'Boat', 'Hostel',
#        'Serviced apartment', 'Cabin', 'Villa', 'Other', 'Hotel', 'Resort',
#        'Boutique hotel', 'Castle', 'Earth house', 'Tent', 'Aparthotel',
#        'Cave', 'Igloo', 'Bus', 'Condohotel', 'Casa particular (Cuba)',
#        'Campsite', "Shepherd's hut (U.K., France)"], dtype=object)

# %%
listing.groupby("property_type")["price"].sum().reset_index().sort_values('price', ascending=False).head(5)
# Out:
#    property_type      price
# 21         House  1113299.0
# 1      Apartment   534084.0
# 14   Condominium   390185.0
# 30     Townhouse   131674.0
# 32         Villa    52586.0
